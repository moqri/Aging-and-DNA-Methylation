# %%
from IPython.display import Image

# %%
# !python glint.py --datafile datafile.txt --covarfile covariates.txt --phenofile phenotypes.txt --gsave
# Out:
# Validating all dependencies are installed...
# You are now running Anaconda Python
# All dependencies are installed
# INFO      >>> python glint.py --datafile datafile.txt --covarfile covariates.txt --phenofile phenotypes.txt --gsave
# INFO      Starting GLINT...
# INFO      Validating arguments...
# INFO      Loading file datafile.txt...
# INFO      Checking for missing values in the data file...
# INFO      Validating phenotypes file...
# INFO      Loading file phenotypes.txt...
# INFO      New phenotypes were found: y1, y2.
# INFO      Validating covariates file...
# INFO      Loading file covariates.txt...
# INFO      New covariates were found: age, gender, chip1, chip2, chip3, chip4, chip5, chip6, chip7, chip8.
# INFO      Loading information about methylation sites...
# INFO      Searching for relevant methylation sites information...
# INFO      Saving CpG names and info to datafile.sites.txt...
# INFO      Saving sample identifiers and their phenotypes and covariates to datafile.samples.txt...
# INFO      Saving methylation data in glint format to datafile.glint...

# %%
# !python glint.py --datafile datafile.glint --plot --plotpcs --numpcs 2 --out pcs_plot
# Out:
# Validating all dependencies are installed...
# You are now running Anaconda Python
# All dependencies are installed
# INFO      >>> python glint.py --datafile datafile.glint --plot --plotpcs --numpcs 2 --out pcs_plot
# INFO      Starting GLINT...
# INFO      Validating arguments...
# INFO      Loading glint file datafile.glint...
# INFO      Running PCA...
# INFO      Plotting first 2 PCs...
# INFO      Saving plot to pcs_plot.png and pcs_plot.eps

# %%
Image(filename='pcs_plot.png')

# %%
# !python glint.py --datafile datafile.glint --maxpcstd 1 4 --gsave --out data_cleaned
# Out:
# Validating all dependencies are installed...
# You are now running Anaconda Python
# All dependencies are installed
# INFO      >>> python glint.py --datafile datafile.glint --maxpcstd 1 4 --gsave --out data_cleaned
# INFO      Starting GLINT...
# INFO      Validating arguments...
# INFO      Loading glint file datafile.glint...
# INFO      Finding samples with standard deviation (STD) higher than 4 STDs or lower than -4 STDs in principal component number 1...
# INFO      Excluding samples according to STDs...
# INFO      Loading information about methylation sites...
# INFO      Searching for relevant methylation sites information...
# INFO      Saving CpG names and info to data_cleaned.sites.txt...
# INFO      Saving sample identifiers and their phenotypes and covariates to data_cleaned.samples.txt...
# INFO      Saving methylation data in glint format to data_cleaned.glint...

# %%
# !python glint.py --datafile data_cleaned.glint --refactor --k 6 --covar age gender chip1 chip2 chip3 chip4 chip5 chip6 chip7 chip8 --gsave --out data_cleaned_v2
# Out:
# Validating all dependencies are installed...
# You are now running Anaconda Python
# All dependencies are installed
# INFO      >>> python glint.py --datafile data_cleaned.glint --refactor --k 6 --covar age gender chip1 chip2 chip3 chip4 chip5 chip6 chip7 chip8 --gsave --out data_cleaned_v2
# INFO      Starting GLINT...
# INFO      Validating arguments...
# INFO      Loading glint file data_cleaned.glint...
# INFO      ReFACTor's arguments: k=6, t=500, num of components=6, minimal std=0.02
# INFO      Starting ReFACTor...
# INFO      ReFACTor is searching for badly designed sites to exclude...
# INFO      9601 sites out of 50000 were excluded (40399 sites left).
# INFO      Excluding sites with variance lower than 0.02...
# INFO      24773 sites out of 40399 were excluded (15626 sites left).
# INFO      Using 'normal' feature selection
# INFO      Using covariates age, gender, chip1, chip2, chip3, chip4, chip5, chip6, chip7, chip8.
# INFO      Regressing out covariates...
# INFO      Computing low rank approximation of the input data and ranking sites...
# INFO      Computing the ReFACTor components...
# INFO      Saving a ranked list of the data features to data_cleaned_v2.refactor.rankedlist.txt...
# INFO      Saving the ReFACTor components to data_cleaned_v2.refactor.components.txt...
# INFO      ReFACTor is done!
# INFO      Adding the ReFACTor componetns to the covariates of the data...
# INFO      Added covariates rc1, rc2, rc3, rc4, rc5, rc6.
# INFO      Loading information about methylation sites...
# INFO      Searching for relevant methylation sites information...
# INFO      Saving CpG names and info to data_cleaned_v2.sites.txt...
# INFO      Saving sample identifiers and their phenotypes and covariates to data_cleaned_v2.samples.txt...
# INFO      Saving methylation data in glint format to data_cleaned_v2.glint...

# %%
# !python glint.py --datafile data_cleaned_v2.glint --epi --covar rc1 rc2 rc3 rc4 rc5 rc6 --gsave --out data_final
# Out:
# Validating all dependencies are installed...
# You are now running Anaconda Python
# All dependencies are installed
# INFO      >>> python glint.py --datafile data_cleaned_v2.glint --epi --covar rc1 rc2 rc3 rc4 rc5 rc6 --gsave --out data_final
# INFO      Starting GLINT...
# INFO      Validating arguments...
# INFO      Loading glint file data_cleaned_v2.glint...
# INFO      Running EPISTRUCTURE...
# INFO      Removing non-informative sites...
# INFO      Including sites...
# INFO      Include sites: 534 CpGs from the reference list of 4913 CpGs will be included...
# INFO      49466 sites out of 50000 were excluded (534 sites left).
# INFO      Using covariates rc1, rc2, rc3, rc4, rc5, rc6.
# INFO      Regressing out covariates...
# INFO      Running PCA...
# INFO      The first 1 PCs were saved to data_final.epistructure.pcs.txt.
# INFO      Added covariates epi1.
# INFO      Loading information about methylation sites...
# INFO      Searching for relevant methylation sites information...
# INFO      Saving CpG names and info to data_final.sites.txt...
# INFO      Saving sample identifiers and their phenotypes and covariates to data_final.samples.txt...
# INFO      Saving methylation data in glint format to data_final.glint...

# %%
# !python glint.py --datafile data_final.glint --ewas --linreg --pheno y1 --covar age gender rc1 rc2 rc3 rc4 rc5 rc6 epi1 --stdth 0.01 --rmxy --rmns --rmpoly
# Out:
# Validating all dependencies are installed...
# You are now running Anaconda Python
# All dependencies are installed
# INFO      >>> python glint.py --datafile data_final.glint --ewas --linreg --pheno y1 --covar age gender rc1 rc2 rc3 rc4 rc5 rc6 epi1 --stdth 0.01 --rmxy --rmns --rmpoly
# INFO      Starting GLINT...
# INFO      Validating arguments...
# INFO      Loading glint file data_final.glint...
# INFO      Searching for sites from X and Y chromosomes to exclude...
# WARNING   Found no sites to exclude.
# INFO      Searching for non-specific sites to exclude...
# INFO      3202 sites out of 50000 were excluded (46798 sites left).
# INFO      Searching for polymorphic sites to exclude...
# INFO      6399 sites out of 46798 were excluded (40399 sites left).
# INFO      Excluding sites with variance lower than 0.01...
# INFO      8066 sites out of 40399 were excluded (32333 sites left).
# INFO      Using phenotype y1.
# INFO      Using covariates age, gender, rc1, rc2, rc3, rc4, rc5, rc6, epi1.
# INFO      Running linear regression test...
# INFO      EWAS linear regression is done!
# INFO      Generating LinReg results file...
# INFO      Loading information about methylation sites...
# INFO      Searching for relevant methylation sites information...
# INFO      LinReg results are saved to file results.glint.linreg.txt.

# %%
# !python glint.py --plot --qqplot --manhattan --results results.glint.linreg.txt
# Out:
# Validating all dependencies are installed...
# You are now running Anaconda Python
# All dependencies are installed
# INFO      >>> python glint.py --plot --qqplot --manhattan --results results.glint.linreg.txt
# INFO      Starting GLINT...
# INFO      Validating arguments...
# INFO      Reading results from file results.glint.linreg.txt.
# WARNING   /home/moqri/tmp/glint/utils/tools.py:15: RuntimeWarning: divide by zero encountered in log10
#   values = -log10(values)
#
# WARNING   /home/moqri/miniconda2/lib/python2.7/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
#
# INFO      Saving plot to results.glint.qqplot.png and results.glint.qqplot.eps
# INFO      Saving plot to results.glint.manhattan.png and results.glint.manhattan.eps

# %%
Image(filename='results.glint.manhattan.png')
